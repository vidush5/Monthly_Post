# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer
import re

# %%
url = 'https://en.wikipedia.org/wiki/Extract, _transform,_load'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Extract, transform, load - Wikipedia</title>
# ...

# %% [markdown]
# ## Search using regex operation

# %%
for tag in soup.find_all('class'):
    print(tag.text)

# %%
for tag in soup.find_all('span', {'class': re.compile("headline")}):
    print(tag.text)
# Out:
# Extract
# Transform
# Load
# Real-life ETL cycle
# Challenges
# Performance
# Parallel processing
# Rerunnability, recoverability
# Virtual ETL
# Dealing with keys
# Tools
# Vs. ELT
# See also
# References

# %% [markdown]
# ## Search by lists

# %%
for item in soup.find_all(["h1","h2","h3"]):
    print(item)
# Out:
# <h1 class="firstHeading" id="firstHeading" lang="en">Extract, transform, load</h1>
# <h2 id="mw-toc-heading">Contents</h2>
# <h2><span class="mw-headline" id="Extract">Extract</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Extract,_transform,_load&amp;action=edit&amp;section=1" title="Edit section: Extract">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h2><span class="mw-headline" id="Transform">Transform</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Extract,_transform,_load&amp;action=edit&amp;section=2" title="Edit section: Transform">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# ...

# %%
for item in soup.find_all(["h1","h2","h3"]):
    print(item.text.strip())
# Out:
# Extract, transform, load
# Contents
# Extract[edit]
# Transform[edit]
# Load[edit]
# Real-life ETL cycle[edit]
# Challenges[edit]
# Performance[edit]
# Parallel processing[edit]
# Rerunnability, recoverability[edit]
# Virtual ETL[edit]
# Dealing with keys[edit]
# Tools[edit]
# Vs. ELT[edit]
# See also[edit]
# References[edit]
# Navigation menu
# Personal tools
# Namespaces
# Variants
# Views
# More
# Search
# Navigation
# Contribute
# Tools
# Print/export
# Languages

# %% [markdown]
# ## Using Functions

# %%
def links_in_para(tag):
    return tag.has_attr('title') and tag.has_attr('href') and not tag.has_attr('class')

# %%
for item in soup.find_all(links_in_para):
    print(item)
# Out:
# <link href="/w/index.php?title=Extract,_transform,_load&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
# <link href="/w/index.php?title=Extract,_transform,_load&amp;action=edit" rel="edit" title="Edit this page"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <a href="/wiki/Talk:Extract,_transform,_load" title="Talk:Extract, transform, load">talk page</a>
# <a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove these template messages</a>
# <a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">references</a>
# <a href="/wiki/Wikipedia:Citing_sources#Inline_citations" title="Wikipedia:Citing sources">inline citations</a>
# <a href="/wiki/Wikipedia:When_to_cite" title="Wikipedia:When to cite">introducing</a>
# ...

# %%
def internal_links(href):
    return href and re.compile("Category").search(href)

# %%
for item in soup.find_all(href=internal_links):
    print(item)
# Out:
# <a href="/wiki/Category:Data_warehousing_products" title="Category:Data warehousing products">Data warehousing products and their producers</a>
# <a href="/wiki/Help:Category" title="Help:Category">Categories</a>
# <a href="/wiki/Category:Extract,_transform,_load_tools" title="Category:Extract, transform, load tools">Extract, transform, load tools</a>
# <a href="/wiki/Category:Data_warehousing" title="Category:Data warehousing">Data warehousing</a>
# <a href="/wiki/Category:Articles_lacking_in-text_citations_from_November_2011" title="Category:Articles lacking in-text citations from November 2011">Articles lacking in-text citations from November 2011</a>
# <a href="/wiki/Category:All_articles_lacking_in-text_citations" title="Category:All articles lacking in-text citations">All articles lacking in-text citations</a>
# ...

# %% [markdown]
# ## SoupStrainer

# %%
a_tags = SoupStrainer("a")
soup = BeautifulSoup(r.text, 'html.parser', parse_only=a_tags)
soup
# Out:
# <a id="top"></a><a class="mw-jump-link" href="#mw-head">Jump to navigation</a><a class="mw-jump-link" href="#searchInput">Jump to search</a><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Extract,_transform,_load&amp;action=edit">improve it</a><a href="/wiki/Talk:Extract,_transform,_load" title="Talk:Extract, transform, load">talk page</a><a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove these template messages</a><a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">references</a><a href="/wiki/Wikipedia:Citing_sources#Inline_citations" title="Wikipedia:Citing sources">inline citations</a><a class="mw-redirect" href="/wiki/Wikipedia:WikiProject_Fact_and_Reference_Check" title="Wikipedia:WikiProject Fact and Reference Check">improve</a><a href="/wiki/Wikipedia:When_to_cite" title="Wikipedia:When to cite">introducing</a><a href="/wiki/Help:Maintenance_template_removal" 
# ...
